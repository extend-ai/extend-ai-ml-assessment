# %%
# Out:
# Cloning into 'synthetic-images'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 21 (delta 6), reused 19 (delta 5), pack-reused 0
# Unpacking objects: 100% (21/21), done.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/extend_AI
# Out:
# /content/gdrive/MyDrive/extend_AI

# %%
ls
# Out:
#  1.jpg   6.jpg          Extend_AI_ASSIGNMENT.ipynb
#  2.jpg   7.jpg          objects/
#  3.jpg   augmented/     preview/
#  4.jpg   Backgrounds/  'Synthetic Image Datasets.ipynb'
#  5.jpg   create.py      synthetic-images/

# %%
# !git clone https://github.com/tylerhutcherson/synthetic-images.git
# Out:
# Cloning into 'synthetic-images'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 21 (delta 6), reused 19 (delta 5), pack-reused 0
# Unpacking objects: 100% (21/21), done.

# %%
# !python python create.py
# Out:
# python3: can't open file 'python': [Errno 2] No such file or directory
